# %%
import pandas as pd
# %matplotlib inline
df = pd.read_csv('students.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          6 non-null      int64
#  1   Name        6 non-null      object
#  2   Attendance  6 non-null      float64
#  3   HW          4 non-null      float64
#  4   Test1       6 non-null      float64
#  5   Project1    6 non-null      float64
#  6   Test2       6 non-null      float64
#  7   Project2    6 non-null      float64
#  8   Final       6 non-null      float64
#  9   datenow     6 non-null      object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'Attendance'}>,
#         <AxesSubplot:title={'center':'HW'}>],
#        [<AxesSubplot:title={'center':'Test1'}>,
#         <AxesSubplot:title={'center':'Project1'}>,
#         <AxesSubplot:title={'center':'Test2'}>],
#        [<AxesSubplot:title={'center':'Project2'}>,
#         <AxesSubplot:title={'center':'Final'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.hist(figsize=(10,8))
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'Attendance'}>,
#         <AxesSubplot:title={'center':'HW'}>],
#        [<AxesSubplot:title={'center':'Test1'}>,
#         <AxesSubplot:title={'center':'Project1'}>,
#         <AxesSubplot:title={'center':'Test2'}>],
#        [<AxesSubplot:title={'center':'Project2'}>,
#         <AxesSubplot:title={'center':'Final'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.Final.hist()
# Out:
# <AxesSubplot:>

# %%
df.Final.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Final.plot()
# Out:
# <AxesSubplot:>

# %%
df.Attendance.value_counts()
# Out:
# 0.84    2
# 0.96    2
# 0.32    1
# 1.00    1
# Name: Attendance, dtype: int64

# %%
df.Attendance.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Attendance'>

# %%
df.Attendance.value_counts().plot(kind='pie',figsize=(8,8))
# Out:
# <AxesSubplot:ylabel='Attendance'>

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<AxesSubplot:xlabel='ID', ylabel='ID'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='ID'>,
#         <AxesSubplot:xlabel='HW', ylabel='ID'>,
#         <AxesSubplot:xlabel='Test1', ylabel='ID'>,
#         <AxesSubplot:xlabel='Project1', ylabel='ID'>,
#         <AxesSubplot:xlabel='Test2', ylabel='ID'>,
#         <AxesSubplot:xlabel='Project2', ylabel='ID'>,
#         <AxesSubplot:xlabel='Final', ylabel='ID'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='HW', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Attendance'>,
#         <AxesSubplot:xlabel='Final', ylabel='Attendance'>],
#        [<AxesSubplot:xlabel='ID', ylabel='HW'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='HW'>,
#         <AxesSubplot:xlabel='HW', ylabel='HW'>,
#         <AxesSubplot:xlabel='Test1', ylabel='HW'>,
#         <AxesSubplot:xlabel='Project1', ylabel='HW'>,
#         <AxesSubplot:xlabel='Test2', ylabel='HW'>,
#         <AxesSubplot:xlabel='Project2', ylabel='HW'>,
#         <AxesSubplot:xlabel='Final', ylabel='HW'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Test1'>,
#         <AxesSubplot:xlabel='HW', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Test1'>,
#         <AxesSubplot:xlabel='Final', ylabel='Test1'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Project1'>,
#         <AxesSubplot:xlabel='HW', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Project1'>,
#         <AxesSubplot:xlabel='Final', ylabel='Project1'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Test2'>,
#         <AxesSubplot:xlabel='HW', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Test2'>,
#         <AxesSubplot:xlabel='Final', ylabel='Test2'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Project2'>,
#         <AxesSubplot:xlabel='HW', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Project2'>,
#         <AxesSubplot:xlabel='Final', ylabel='Project2'>],
#        [<AxesSubplot:xlabel='ID', ylabel='Final'>,
#         <AxesSubplot:xlabel='Attendance', ylabel='Final'>,
#         <AxesSubplot:xlabel='HW', ylabel='Final'>,
#         <AxesSubplot:xlabel='Test1', ylabel='Final'>,
#         <AxesSubplot:xlabel='Project1', ylabel='Final'>,
#         <AxesSubplot:xlabel='Test2', ylabel='Final'>,
#         <AxesSubplot:xlabel='Project2', ylabel='Final'>,
#         <AxesSubplot:xlabel='Final', ylabel='Final'>]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          6 non-null      int64
#  1   Name        6 non-null      object
#  2   Attendance  6 non-null      float64
#  3   HW          4 non-null      float64
#  4   Test1       6 non-null      float64
#  5   Project1    6 non-null      float64
#  6   Test2       6 non-null      float64
#  7   Project2    6 non-null      float64
#  8   Final       6 non-null      float64
#  9   datenow     6 non-null      object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 608.0+ bytes

# %%
df.plot(x='Test1', y='Final', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Test1', ylabel='Final'>

# %%
df.Final.plot(kind='box')
# Out:
# <AxesSubplot:>
