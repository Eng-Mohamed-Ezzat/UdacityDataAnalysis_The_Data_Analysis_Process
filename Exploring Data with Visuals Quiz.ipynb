# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below. Remember, you created this dataset at the bottom of the notebook in the "Reading CSV Files" section earlier in the lesson! Check your work with the solutions on that page if you are having trouble getting this dataset.

# %%
# import and load data
import pandas as pd
# %matplotlib inline
df = pd.read_csv('powerplant_data.csv', names=['temperature','exhaust_vacuum','pressure','humidity','energy_output'], header=0)
df.head()
# Out:
#    temperature  exhaust_vacuum  pressure  humidity  energy_output
# 0         8.34           40.77   1010.84     90.01         480.48
# 1        23.64           58.49   1011.40     74.20         445.75
# 2        29.74           56.90   1007.15     41.91         438.76
# 3        19.07           49.69   1007.22     76.79         453.09
# 4        11.80           40.66   1017.13     97.20         464.43

# %%
# plot relationship between temperature and electrical output
df.plot('temperature','energy_output', kind='scatter')
# Out:
# <AxesSubplot:xlabel='temperature', ylabel='energy_output'>

# %%
# plot distribution of humidity
df.humidity.hist()
# Out:
# <AxesSubplot:>

# %%
# plot box plots for each variable
df.plot(figsize=(10,10), kind='box')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['temperature', 'exhaust_vacuum', 'pressure', 'humidity',
#        'energy_output'],
#       dtype='object')

# %%
df['temperature'].plot(kind='box');

# %%
df['exhaust_vacuum'].plot(kind='box');

# %%
df['pressure'].plot(kind='box');

# %%
df['humidity'].plot(kind='box');

# %%
df['energy_output'].plot(kind='box');
